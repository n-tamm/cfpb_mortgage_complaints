# %% [markdown]
# # Supervised Model Development
#
# This notebook implements the supervised-learning workflow for predicting whether a banking complaint ends with any consumer monetary relief or no relief. The primary source file is `data/processed/final_unsupervised_features_relief_vader.parquet`. Due to size limitations, the data is not available on Github, however, please see the sample_data folder of the repo for a glimpse into 1000 examples records.
#
# AI Assistance:
# OpenAI ChatGPT was used for code debugging, code generation, code organization,
# and code methodological brainstorming. All final modeling, implementation,
# validation, commentary, and interpretation were performed and verified by the authors.
#
# ## Final Narrative-Subset Model Development

# %%
# pip install -r ../requirements.txt

# %% [markdown]
# ## Notebook Overview
#
# This notebook is the narrative-subset companion to the all-records final development notebook.
#
# The purpose is to answer a cleaner question:
#
# - baseline notebook: how well can we predict monetary relief across all complaints using features available for every record?
# - narrative notebook: among complaints that include a consumer narrative, how much extra signal can we unlock from lightweight text features?
#
# The target remains binary:
#
# - `1` = `Closed with monetary relief`
# - `0` = every other company response value in the filtered relief dataset
#
# This notebook filters to `narrative_present == 1` before modeling, keeps the same structured context, and uses narrative-derived features in a setting where they are available for every observation.

# %% [markdown]
# ## Table of Contents
#
# 1. [Data Loading and Exploration](#Data-Loading-and-Exploration)
# 2. [Feature Engineering](#Feature-Engineering)
# 3. [Train/Test Setup](#Train/Test-Setup)
# 4. [Model #1 Logistic Regression](#Model-#1-Logistic-Regression)
# 5. [Model #2 KNN](#Model-#2-KNN)
# 6. [Model #3 Random Forest](#Model-#3-Random-Forest)
# 7. [Model #4 Support Vector Machine](#Model-#4-Support-Vector-Machine)
# 8. [Final Model Selection](#Final-Model-Selection)

# %% [markdown]
# ### Data Loading and Exploration
#
# We start by validating that the final_unsupervised_features_relief_vader parquet is internally consistent enough for supervised learning. Before training any model, we check for duplicate complaint identifiers, target completeness, date parsing issues, negative date gaps, and the amount of missingness in high-value fields such as the narrative to make sure we are all set with our finalized filtered dataset.

# %%
import os
from pathlib import Path
import warnings

import joblib
from imblearn.over_sampling import SMOTE
from imblearn.pipeline import Pipeline as ImbPipeline
import numpy as np
import pandas as pd

from IPython.display import display
from sklearn.compose import ColumnTransformer
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import (
    accuracy_score,
    average_precision_score,
    balanced_accuracy_score,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
)
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.svm import LinearSVC

warnings.filterwarnings("ignore")
pd.set_option("display.max_columns", 100)

PROJECT_ROOT = Path.cwd().resolve().parent if Path.cwd().name == "notebooks" else Path.cwd().resolve()
DATA_PATH = PROJECT_ROOT / "data" / "processed" / "final_unsupervised_features_relief_vader.parquet"
ARTIFACT_DIR = PROJECT_ROOT / "data" / "processed"
VISUALS_DIR = PROJECT_ROOT / "visuals"
VISUALS_DIR.mkdir(exist_ok=True)
OUTPUT_TABLES_DIR = PROJECT_ROOT / "output_tables"
OUTPUT_TABLES_DIR.mkdir(exist_ok=True)

MODEL_SCOPE = "all_banking_relief_final_narrative"
QUICK_TEST_MODE = False
RANDOM_STATE = 42
CV_FOLDS = 5 if not QUICK_TEST_MODE else 3
MAX_MODEL_ROWS = 120000 if not QUICK_TEST_MODE else 30000
KNN_MAX_TRAIN_ROWS = 15000 if not QUICK_TEST_MODE else 5000
RF_N_ESTIMATORS = 225 if not QUICK_TEST_MODE else 100
N_JOBS = min(4, max(1, (os.cpu_count() or 2) - 1))

assert DATA_PATH.exists(), f"Expected sentiment-enriched relief parquet at {DATA_PATH}"

raw_df = pd.read_parquet(DATA_PATH)
raw_df = raw_df.loc[~raw_df["Company response to consumer"].isin(["Untimely response", "In progress"])].copy()

print(f"Loaded {len(raw_df):,} rows and {raw_df.shape[1]} columns from {DATA_PATH.name}")
raw_df.head()
# Out:
# Loaded 397,575 rows and 44 columns from final_unsupervised_features_relief_vader.parquet
#   Date received                      Product  \
# 0    2019-11-18  Credit card or prepaid card
# 1    2020-04-10  Credit card or prepaid card
# 2    2019-07-09  Credit card or prepaid card
# 3    2020-07-10  Credit card or prepaid card
# 4    2019-06-24  Credit card or prepaid card
#
#                                   Sub-product  \
# 0  General-purpose credit card or charge card
# 1                General-purpose prepaid card
# 2                           Store credit card
# 3  General-purpose credit card or charge card
# 4  General-purpose credit card or charge card
#
#                                                Issue  \
# 0    Problem with a purchase shown on your statement
# 1                             Trouble using the card
# 2    Problem with a purchase shown on your statement
# 3                            Trouble using your card
# 4  Advertising and marketing, including promotion...
#
#                                            Sub-issue  \
# 0  Credit card company isn't resolving a dispute ...
# 1         Trouble getting information about the card
# 2  Card was charged for something you did not pur...
# 3                   Can't use card to make purchases
# 4  Confusing or misleading advertising about the ...
#
#                         Consumer complaint narrative  \
# 0  XXXX claimed they delivered a package to my ad...
# 1  I got a Brinks Money pre-paid card in the mail...
# 2  On XX/XX/XXXX I was called by a creditor Nelso...
# 3  Around XX/XX/2020 i XXXX XXXX XXXX opened a cr...
# 4  Equifax sent me credit card suggestions to hel...
#
#                              Company public response  \
# 0                                                NaN
# 1  Company has responded to the consumer and the ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                              Company State ZIP code Tags  \
# 0                      DISCOVER BANK    MA    021XX  NaN
# 1               Netspend Corporation    IL    60657  NaN
# 2       Nelson Cruz & Associates LLC    TN    37043  NaN
# 3  CAPITAL ONE FINANCIAL CORPORATION    CA    937XX  NaN
# 4                      EQUIFAX, INC.    OR    971XX  NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0           Consent provided           Web           2019-11-18
# 1           Consent provided           Web           2020-04-14
# 2           Consent provided           Web           2019-07-09
# 3           Consent provided           Web           2020-07-10
# 4           Consent provided           Web           2019-06-24
#
#   Company response to consumer  Timely response? Consumer disputed?  \
# 0      Closed with explanation              True                N/A
# 1      Closed with explanation              True                N/A
# 2      Closed with explanation              True                N/A
# 3      Closed with explanation              True                N/A
# 4      Closed with explanation              True                N/A
#
#    Complaint ID                         cleaned_consumer_narrative  \
# 0       3442136  REDACTED claimed they delivered a package to m...
# 1       3601853  I got a Brinks Money pre-paid card in the mail...
# 2       3300820  On REDACTED_DATE I was called by a creditor Ne...
# 3       3739698  Around REDACTED / REDACTED /2020 i REDACTED RE...
# 4       3285243  Equifax sent me credit card suggestions to hel...
#
#                                  processed_narrative  cluster  \
# 0  claimed delivered package address never receiv...       11
# 1  got brink money pre paid card mail assuming un...        3
# 2  called creditor nelson cruz associate claimed ...       44
# 3  around opened credit card account online capit...       25
# 4  equifax sent credit card suggestion help impro...       44
#
#    distance_to_centroid  dominant_topic  topic_0_prob  topic_1_prob  \
# 0              0.992864              10      0.000602      0.000602
# 1              0.998468               8      0.002174      0.002174
# 2              0.978543               9      0.000926      0.085328
# 3              0.852135               2      0.000538      0.000538
# 4              0.963603               6      0.002083      0.002083
#
#    topic_2_prob  topic_3_prob  topic_4_prob  topic_5_prob  topic_6_prob  \
# 0      0.000602      0.000602      0.000602      0.000602      0.000602
# 1      0.276566      0.002174      0.002174      0.002174      0.002174
# 2      0.147042      0.000926      0.000926      0.000926      0.000926
# 3      0.426388      0.000538      0.000538      0.000538      0.000538
# 4      0.002083      0.002083      0.002083      0.179421      0.783079
#
#    topic_7_prob  topic_8_prob  topic_9_prob  topic_10_prob  topic_11_prob  \
# 0      0.000602      0.000602      0.154693       0.712191       0.000602
# 1      0.002174      0.503805      0.002174       0.002174       0.002174
# 2      0.068550      0.186560      0.386073       0.000926       0.077052
# 3      0.000538      0.183611      0.320316       0.018011       0.000538
# 4      0.002083      0.002083      0.002083       0.002083       0.002083
#
#    topic_12_prob  topic_13_prob  topic_14_prob  topic_15_prob  topic_16_prob  \
# 0       0.061553       0.000602       0.000602       0.000602       0.000602
# 1       0.002174       0.182673       0.002174       0.002174       0.002174
# 2       0.000926       0.000926       0.000926       0.000926       0.037359
# 3       0.000538       0.000538       0.000538       0.000538       0.000538
# 4       0.002083       0.002083       0.002083       0.002083       0.002083
#
#    topic_17_prob  topic_18_prob  topic_19_prob  narrative_sentiment_score
# 0       0.000602       0.061924       0.000602                     0.4019
# 1       0.002174       0.002174       0.002174                     0.0000
# 2       0.000926       0.000926       0.000926                    -0.8002
# 3       0.000538       0.000538       0.043609                     0.8060
# 4       0.002083       0.002083       0.002083                     0.8591

# %%
quality_df = raw_df.copy()
quality_df["Date received"] = pd.to_datetime(quality_df["Date received"], errors="coerce")
quality_df["Date sent to company"] = pd.to_datetime(quality_df["Date sent to company"], errors="coerce")
quality_df["company_lag_days"] = (
    quality_df["Date sent to company"] - quality_df["Date received"]
).dt.days

positive_relief_values = ["Closed with monetary relief"]

quality_summary = pd.DataFrame(
    {
        "dtype": raw_df.dtypes.astype(str),
        "missing_count": raw_df.isna().sum(),
        "missing_pct": (raw_df.isna().mean() * 100).round(2),
        "n_unique": raw_df.nunique(dropna=True),
    }
).sort_values(["missing_pct", "n_unique"], ascending=[False, False])

data_quality_checks = pd.Series(
    {
        "rows": len(raw_df),
        "columns": raw_df.shape[1],
        "duplicate_rows": int(raw_df.duplicated().sum()),
        "duplicate_complaint_ids": int(raw_df["Complaint ID"].duplicated().sum()),
        "null_target_count": int(raw_df["Company response to consumer"].isna().sum()),
        "unparseable_date_received": int(quality_df["Date received"].isna().sum()),
        "unparseable_date_sent": int(quality_df["Date sent to company"].isna().sum()),
        "negative_lag_rows": int((quality_df["company_lag_days"] < 0).sum()),
        "narrative_missing_pct": round(raw_df["Consumer complaint narrative"].isna().mean() * 100, 2),
        "target_relief_pct": round(raw_df["Company response to consumer"].isin(positive_relief_values).mean() * 100, 3),
    },
    name="value",
)

display(data_quality_checks.to_frame())
display(quality_summary.head(15))
display(quality_df["company_lag_days"].describe(percentiles=[0.01, 0.05, 0.5, 0.95, 0.99]).to_frame().T)
# Out:
#                                 value
# rows                       397575.000
# columns                        44.000
# duplicate_rows                  0.000
# duplicate_complaint_ids         0.000
# null_target_count               0.000
# unparseable_date_received       0.000
# unparseable_date_sent           0.000
# negative_lag_rows               0.000
# narrative_missing_pct           0.000
# target_relief_pct              15.719
#                                 dtype  missing_count  missing_pct  n_unique
# Tags                              str         314638        79.14         3
# Company public response           str         208623        52.47        10
# Consumer complaint narrative      str              0         0.00    397575
# Complaint ID                    int64              0         0.00    397575
# cleaned_consumer_narrative        str              0         0.00    397575
# processed_narrative               str              0         0.00    397575
# distance_to_centroid          float64              0         0.00    397214
# topic_2_prob                  float64              0         0.00    397115
# topic_12_prob                 float64              0         0.00    397115
# topic_1_prob                  float64              0         0.00    397114
# topic_7_prob                  float64              0         0.00    397114
# topic_9_prob                  float64              0         0.00    397114
# topic_11_prob                 float64              0         0.00    397114
# topic_4_prob                  float64              0         0.00    397113
# topic_15_prob                 float64              0         0.00    397113
#                      count      mean       std  min   1%   5%  50%  95%   99%  \
# company_lag_days  397575.0  1.187532  6.251914  0.0  0.0  0.0  0.0  6.0  33.0
#
#                     max
# company_lag_days  446.0

# %% [markdown]
# The quality check still does its usual job here, but the design implications are more focused in the final notebook:
#
# - the target rate now reflects monetary relief only, which is the right binary framing for this final notebook
# - the narrative is now complete with lightweight derived features and more computationally complex features derived with LDA
# - very sparse fields remain poor candidates for prediction use, so the feature set stays selective rather than expansive
# - the final notebook is intentionally conservative about feature growth: we would rather add a few strong signals than flood the models with weak ones. This tradeoff becomes apparent when comparing this narrative notebook to the final_clean notebook

# %%
product_summary = (
    raw_df.groupby("Product", dropna=False)
    .agg(
        complaints=("Complaint ID", "count"),
        relief_rate=("Company response to consumer", lambda s: s.isin(["Closed with monetary relief"]).mean()),
        narrative_available=("Consumer complaint narrative", lambda s: s.notna().mean()),
    )
    .sort_values("complaints", ascending=False)
)
product_summary[["relief_rate", "narrative_available"]] = (
    product_summary[["relief_rate", "narrative_available"]] * 100
).round(2)

display(product_summary)
display(raw_df["Company response to consumer"].value_counts(dropna=False).rename("count").to_frame())

high_null_columns = quality_summary.loc[quality_summary["missing_pct"] >= 20, ["missing_pct", "n_unique"]]
display(high_null_columns)
# Out:
#                              complaints  relief_rate  narrative_available
# Product
# Checking or savings account      170983        15.43                100.0
# Credit card or prepaid card      100503        19.06                100.0
# Credit card                       89765        18.11                100.0
# Mortgage                          36324         1.93                100.0
#                                   count
# Company response to consumer
# Closed with explanation          302126
# Closed with monetary relief       62496
# Closed with non-monetary relief   32953
#                          missing_pct  n_unique
# Tags                           79.14         3
# Company public response        52.47        10

# %% [markdown]
# Overall, the initial quality check shows a few important findings that shape the rest of the notebook:
#
# - The processed banking dataset is large enough for supervised learning at over 400k records even with our filtered down subset.
# - `Complaint ID` appears unique and the date fields parse cleanly, which reduces the need for dedup logic or date parsing.
# - The filtered relief-response dataset is much more balanced than the untimely response dataset, so we use explicit imbalance handling and tractability controls in this notebook because the relief dataset is larger and may still benefit from rebalancing depending on the final class mix.
# - Narrative coverage is still meaningful but incomplete, which motivates combining simple narrative indicators with structured complaint context.
# - Missingness is concentrated in fields like `Tags` and `Company public response`, which make them unlikely to be useful. Furthermore, `Consumer complaint narrative` and `Sub-issue` also contain missing values, so our preprocessing needs robust imputers and careful leakage handling.
#
# The product summary also confirms that this is a banking problem rather than a single product classification task. That variety is one reason we preserve `Product`, `Issue`, channel, and company context as predictive inputs.

# %% [markdown]
# ### Feature Engineering
#
# We intentionally exclude fields that are likely to leak post-submission or post-resolution information into the prediction task. In particular, `Date sent to company`, `Timely response?`, `Company public response`, and `Consumer disputed?` are better suited for diagnostics than for prediction of the company monetary/non-monetary response outcome.
#
# Our feature design tries to balance predictive power with practicality. If a feature is only known after the complaint has already been processed by the company, we exclude it from model training even if it would make prediction easier.
#
# Narrative information in this notebook still includes some simple features:
#
# - whether a narrative is present
# - basic narrative length measures such as character and word count
#
# Additional features for topic_probs have been added from our Unsupervised LDA analysis.

# %%
def make_one_hot_encoder(dense=False):
    kwargs = {"handle_unknown": "ignore"}
    try:
        return OneHotEncoder(sparse_output=not dense, **kwargs)
    except TypeError:
        return OneHotEncoder(sparse=not dense, **kwargs)


POSITIVE_RELIEF_VALUES = ["Closed with monetary relief"]
TOPIC_CLUSTER_CANDIDATES = [
    "narrative_topic_cluster",
    "topic_cluster",
    "complaint_topic_cluster",
    "narrative_cluster",
]


def score_estimator(estimator, X_test, y_test):
    if hasattr(estimator, "predict_proba"):
        y_score = estimator.predict_proba(X_test)[:, 1]
    else:
        y_score = estimator.decision_function(X_test)
    y_pred = estimator.predict(X_test)
    return {
        "holdout_accuracy": accuracy_score(y_test, y_pred),
        "holdout_average_precision": average_precision_score(y_test, y_score),
        "holdout_roc_auc": roc_auc_score(y_test, y_score),
        "holdout_recall": recall_score(y_test, y_pred, zero_division=0),
        "holdout_precision": precision_score(y_test, y_pred, zero_division=0),
        "holdout_f1": f1_score(y_test, y_pred, zero_division=0),
        "holdout_balanced_accuracy": balanced_accuracy_score(y_test, y_pred),
        "y_score": y_score,
        "y_pred": y_pred,
    }


def build_results_row(model_name, search, X_test, y_test):
    best_idx = search.best_index_
    metric_names = [
        "accuracy",
        "average_precision",
        "roc_auc",
        "recall",
        "precision",
        "f1",
        "balanced_accuracy",
    ]
    row = {
        "model_family": model_name,
        "best_params": search.best_params_,
    }
    for metric in metric_names:
        row[f"cv_mean_{metric}"] = search.cv_results_[f"mean_test_{metric}"][best_idx]
        row[f"cv_std_{metric}"] = search.cv_results_[f"std_test_{metric}"][best_idx]

    holdout_scores = score_estimator(search.best_estimator_, X_test, y_test)
    row.update({k: v for k, v in holdout_scores.items() if not k.startswith("y_")})
    return row, holdout_scores


leakage_columns = [
    "Timely response?",
    "Date sent to company",
    "Company response to consumer",
    "Company public response",
    "Consumer disputed?",
    "Consumer consent provided?",
]

model_df = raw_df.copy()
model_df["Date received"] = pd.to_datetime(model_df["Date received"], errors="coerce")
model_df["target_relief"] = model_df["Company response to consumer"].isin(POSITIVE_RELIEF_VALUES).astype(int)

text_series = model_df["Consumer complaint narrative"].fillna("")
model_df["narrative_present"] = text_series.str.len().gt(0).astype(int)
model_df["narrative_char_count"] = text_series.str.len()
model_df["narrative_word_count"] = text_series.str.split().str.len().fillna(0)

if "narrative_sentiment_score" not in model_df.columns:
    raise KeyError("Expected precomputed 'narrative_sentiment_score' column. Run notebooks/02b_narrative_sentiment.ipynb first.")

topic_cluster_features = [col for col in TOPIC_CLUSTER_CANDIDATES if col in model_df.columns]
for col in topic_cluster_features:
    model_df[col] = model_df[col].fillna("missing").astype(str)

model_df["received_year"] = model_df["Date received"].dt.year
model_df["received_month"] = model_df["Date received"].dt.month
model_df["received_quarter"] = model_df["Date received"].dt.quarter
model_df["received_dayofweek"] = model_df["Date received"].dt.dayofweek
model_df["received_day"] = model_df["Date received"].dt.day
model_df["zip3"] = (
    model_df["ZIP code"].fillna("").astype(str).str.extract(r"(\d{3})", expand=False).fillna("missing")
)

top_category_limits = {
    "Company": 60 if QUICK_TEST_MODE else 100,
    "Sub-product": 20 if QUICK_TEST_MODE else 35,
    "Issue": 25 if QUICK_TEST_MODE else 45,
    "Sub-issue": 35 if QUICK_TEST_MODE else 70,
}
for col, top_n in top_category_limits.items():
    values = model_df[col].fillna("missing").astype(str)
    keep = set(values.value_counts().head(top_n).index)
    model_df[col] = values.where(values.isin(keep), other="__OTHER__")

model_df["Submitted via"] = model_df["Submitted via"].fillna("missing").astype(str)
model_df["Product"] = model_df["Product"].fillna("missing").astype(str)

usable_columns = [col for col in model_df.columns if col not in leakage_columns]
model_df = model_df[usable_columns].dropna(subset=["Date received", "target_relief"]).copy()
model_df = model_df.loc[model_df["narrative_present"].eq(1)].copy()

if len(model_df) > MAX_MODEL_ROWS:
    _, model_df = train_test_split(
        model_df,
        test_size=MAX_MODEL_ROWS,
        stratify=model_df["target_relief"],
        random_state=RANDOM_STATE,
    )

display(model_df.head())
print(f"Narrative-only modeling rows after filtering: {len(model_df):,}")
print(f"Narrative-only monetary relief rate: {model_df['target_relief'].mean() * 100:.3f}%")
print(f"Topic-cluster features detected: {topic_cluster_features if topic_cluster_features else 'none yet'}")
# Out:
#        Date received                      Product  \
# 3098      2020-01-09  Credit card or prepaid card
# 103540    2018-02-08  Checking or savings account
# 270594    2024-01-29                     Mortgage
# 74997     2023-11-27  Checking or savings account
# 297136    2023-10-08                     Mortgage
#
#                                        Sub-product  \
# 3098    General-purpose credit card or charge card
# 103540                            Checking account
# 270594                  Conventional home mortgage
# 74997                             Checking account
# 297136                  Conventional home mortgage
#
#                                                     Issue  \
# 3098      Problem with a purchase shown on your statement
# 103540                                 Opening an account
# 270594                     Trouble during payment process
# 74997                                 Managing an account
# 297136  Applying for a mortgage or refinancing an exis...
#
#                                                 Sub-issue  \
# 3098    Card was charged for something you did not pur...
# 103540          Didn't receive terms that were advertised
# 270594  Trying to communicate with the company to fix ...
# 74997                   Problem using a debit or ATM card
# 297136                                          __OTHER__
#
#                              Consumer complaint narrative  \
# 3098    On XX/XX/2020, I went into my bank account to ...
# 103540  On XX/XX/XXXX, I opened a Citibank Account Pac...
# 270594  In XX/XX/2023 we applied for a principal curta...
# 74997   Been a customer for almost 2 years. Had a repl...
# 297136  I had received a letter from state, three year...
#
#                                      Company State ZIP code Tags  \
# 3098                   WELLS FARGO & COMPANY    CA    92672  NaN
# 103540                        CITIBANK, N.A.    CA    90024  NaN
# 270594  United Shore Financial Services, LLC    TN    374XX  NaN
# 74997                              __OTHER__    CO    80205  NaN
# 297136        NEW YORK COMMUNITY BANCORP INC    CA    90604  NaN
#
#        Submitted via  Complaint ID  \
# 3098             Web       3490683
# 103540           Web       2808333
# 270594           Web       8239106
# 74997            Web       7909093
# 297136           Web       7661760
#
#                                cleaned_consumer_narrative  \
# 3098    On REDACTED / REDACTED /2020, I went into my b...
# 103540  On REDACTED_DATE , I opened a Citibank Account...
# 270594  In REDACTED / REDACTED /2023 we applied for a ...
# 74997   Been a customer for almost 2 years. Had a repl...
# 297136  I had received a letter from state, three year...
#
#                                       processed_narrative  cluster  \
# 3098    went bank account check statement noticed cred...        6
# 103540  opened citibank account package checking accou...       42
# 270594  applied principal curtailment loan recast appr...       26
# 74997   customer almost year replacement card stolen u...       18
# 297136  received letter state three year brother owned...       32
#
#         distance_to_centroid  dominant_topic  topic_0_prob  topic_1_prob  \
# 3098                0.965072               2      0.000459      0.118154
# 103540              0.886301              15      0.000532      0.000532
# 270594              0.982504              13      0.076498      0.146219
# 74997               0.959723               8      0.000289      0.000289
# 297136              0.981038               3      0.000362      0.000362
#
#         topic_2_prob  topic_3_prob  topic_4_prob  topic_5_prob  topic_6_prob  \
# 3098        0.455229      0.000459      0.000459      0.205911      0.112035
# 103540      0.000532      0.000532      0.295650      0.000532      0.000532
# 270594      0.136955      0.098328      0.095437      0.000240      0.000240
# 74997       0.237072      0.000289      0.000289      0.120216      0.000289
# 297136      0.000362      0.597497      0.000362      0.000362      0.000362
#
#         topic_7_prob  topic_8_prob  topic_9_prob  topic_10_prob  \
# 3098        0.000459      0.000459      0.000459       0.000459
# 103540      0.000532      0.000532      0.000532       0.000532
# 270594      0.000240      0.000240      0.000240       0.000240
# 74997       0.000289      0.282905      0.000289       0.000289
# 297136      0.000362      0.044476      0.000362       0.000362
#
#         topic_11_prob  topic_12_prob  topic_13_prob  topic_14_prob  \
# 3098         0.011033       0.000459       0.000459       0.048028
# 103540       0.000532       0.000532       0.000532       0.000532
# 270594       0.000240       0.000240       0.443198       0.000240
# 74997        0.126285       0.169310       0.000289       0.000289
# 297136       0.000362       0.000362       0.246530       0.105700
#
#         topic_15_prob  topic_16_prob  topic_17_prob  topic_18_prob  \
# 3098         0.000459       0.000459       0.000459       0.000459
# 103540       0.681927       0.000532       0.013381       0.000532
# 270594       0.000240       0.000240       0.000240       0.000240
# 74997        0.060166       0.000289       0.000289       0.000289
# 297136       0.000362       0.000362       0.000362       0.000362
#
#         topic_19_prob  narrative_sentiment_score  target_relief  \
# 3098         0.043647                    -0.3395              1
# 103540       0.000532                     0.9531              1
# 270594       0.000240                     0.3182              0
# 74997        0.000289                    -0.9224              0
# 297136       0.000362                     0.9912              0
#
#         narrative_present  narrative_char_count  narrative_word_count  \
# 3098                    1                  1356                   252
# 103540                  1                  1195                   186
# 270594                  1                  2649                   463
# 74997                   1                  2217                   399
# 297136                  1                  2279                   417
#
#         received_year  received_month  received_quarter  received_dayofweek  \
# 3098             2020               1                 1                   3
# 103540           2018               2                 1                   3
# 270594           2024               1                 1                   0
# 74997            2023              11                 4                   0
# 297136           2023              10                 4                   6
#
#         received_day zip3
# 3098               9  926
# 103540             8  900
# 270594            29  374
# 74997             27  802
# 297136             8  906
# Narrative-only modeling rows after filtering: 120,000
# Narrative-only monetary relief rate: 15.719%
# Topic-cluster features detected: none yet

# %% [markdown]
# A few design choices here:
#
# - This notebook filters to records with narratives so that text-derived features are always genuinely available.
# - The goal is not to replace the all-records baseline, but to test whether narrative-aware modeling earns a measurable gain on the narrative subset. Which may be indicative of needing to encourage consumers to fill out complaints with all requested fields populated.
# - We keep the same cautious missing value handling and the same exclusion of `received_days_since_start` to avoid accidental temporal leakage.

# %% [markdown]
# ### Train/Test Setup
#
# We again use a stratified split and stratified cross-validation, but now the population is restricted to complaints where a narrative exists. That makes the evaluation cleaner because the text-derived features are no longer missing by design for part of the dataset.
#
# For the final notebooks, the non-tree models also get a slightly broader search space than the quick relief draft did, but the grids are still intentionally selective so runtime grows in a controlled way rather than exploding from low-value combinations.

# %%
target_col = "target_relief"

structured_numeric = [
    "received_year",
    "received_month",
    "received_quarter",
    "received_dayofweek",
    "received_day",
    "narrative_present",
    "narrative_char_count",
    "narrative_word_count",
    "narrative_sentiment_score",
    # "distance_to_centroid",
    "topic_0_prob",
    "topic_1_prob",
    "topic_2_prob",
    "topic_3_prob",
    "topic_4_prob",
    "topic_5_prob",
    "topic_6_prob",
    "topic_7_prob",
    "topic_8_prob",
    "topic_9_prob",
    "topic_10_prob",
    "topic_11_prob",
    "topic_12_prob",
    "topic_13_prob",
    "topic_14_prob",
    "topic_15_prob",
    "topic_16_prob",
    "topic_17_prob",
    "topic_18_prob",
    "topic_19_prob",
]

shared_topic_features = topic_cluster_features.copy()

logistic_categorical = [
    "Product",
    "Sub-product",
    "Issue",
    "Sub-issue",
    "Company",
    "Submitted via",
] + shared_topic_features

# Simplified categorical features for KNN to avoid high-dimensional sparse space issues
knn_categorical = ["Product", "Issue", "Submitted via"] + shared_topic_features
rf_categorical = [
    "Product",
    "Sub-product",
    "Issue",
    "Sub-issue",
    "Company",
    "Submitted via",
] + shared_topic_features

logistic_features = logistic_categorical + structured_numeric
knn_features = knn_categorical + structured_numeric
rf_features = rf_categorical + structured_numeric

train_df, test_df = train_test_split(
    model_df,
    test_size=0.2,
    stratify=model_df[target_col],
    random_state=RANDOM_STATE,
)

scoring = {
    "accuracy": "accuracy",
    "average_precision": "average_precision",
    "roc_auc": "roc_auc",
    "recall": "recall",
    "precision": "precision",
    "f1": "f1",
    "balanced_accuracy": "balanced_accuracy",
}
cv = StratifiedKFold(n_splits=CV_FOLDS, shuffle=True, random_state=RANDOM_STATE)

print(f"Train rows: {len(train_df):,}")
print(f"Test rows: {len(test_df):,}")
print(f"Train relief rate: {train_df[target_col].mean() * 100:.3f}%")
print(f"Test relief rate: {test_df[target_col].mean() * 100:.3f}%")
print(f"Grid-search workers: {N_JOBS}")
print(f"Quick test mode: {QUICK_TEST_MODE}")
print(f"Max modeling rows: {MAX_MODEL_ROWS}")
print(f"KNN train-row cap: {KNN_MAX_TRAIN_ROWS}")
print(f"Logistic grid points: {len(logistic_grid) if 'logistic_grid' in globals() else 'defined later'}")
print(f"Detected topic-cluster features: {shared_topic_features if shared_topic_features else 'none yet'}")
# Out:
# Train rows: 96,000
# Test rows: 24,000
# Train relief rate: 15.719%
# Test relief rate: 15.721%
# Grid-search workers: 4
# Quick test mode: False
# Max modeling rows: 120000
# KNN train-row cap: 15000
# Logistic grid points: 1
# Detected topic-cluster features: none yet

# %% [markdown]
# ### Model #1 Logistic Regression
#
# Logistic regression remains our strongest linear baseline. In the final notebook, it gets the cleaner feature set, a sentiment score, and company context. That gives it a fair chance to compete without turning the run into a huge sparse-matrix exercise.

# %%
logistic_preprocessor = ColumnTransformer(
    transformers=[
        (
            "cat",
            Pipeline(
                steps=[
                    ("imputer", SimpleImputer(strategy="constant", fill_value="missing")),
                    ("onehot", make_one_hot_encoder(dense=False)),
                ]
            ),
            logistic_categorical,
        ),
        (
            "num",
            Pipeline(
                steps=[
                    ("imputer", SimpleImputer(strategy="median")),
                    ("scaler", StandardScaler()),
                ]
            ),
            structured_numeric,
        ),
    ]
)

logistic_pipeline = Pipeline(
    steps=[
        ("preprocessor", logistic_preprocessor),
        (
            "model",
            LogisticRegression(
                class_weight="balanced",
                max_iter=900,
                solver="saga",
                tol=5e-4,
                random_state=RANDOM_STATE,
            ),
        ),
    ]
)

logistic_grid = {
    "model__C": [0.15, 0.35, 0.75, 1.5, 3.0],
}

logistic_search = GridSearchCV(
    estimator=logistic_pipeline,
    param_grid=logistic_grid,
    scoring=scoring,
    refit="f1",
    cv=cv,
    n_jobs=N_JOBS,
    verbose=1,
)

X_train_log = train_df[logistic_features]
y_train_log = train_df[target_col]
X_test_log = test_df[logistic_features]
y_test_log = test_df[target_col]

logistic_search.fit(X_train_log, y_train_log)
logistic_row, logistic_scores = build_results_row("Logistic Regression", logistic_search, X_test_log, y_test_log)

logistic_holdout = test_df[["Complaint ID", "Product", "Issue", "Company", "narrative_present", target_col]].copy()
logistic_holdout["model_family"] = "Logistic Regression"
logistic_holdout["score"] = logistic_scores["y_score"]
logistic_holdout["prediction"] = logistic_scores["y_pred"]

display(pd.DataFrame([logistic_row]).T)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
#                                              0
# model_family               Logistic Regression
# best_params                 {'model__C': 0.35}
# cv_mean_accuracy                       0.69475
# cv_std_accuracy                       0.002788
# cv_mean_average_precision             0.402923
# cv_std_average_precision              0.001785
# cv_mean_roc_auc                       0.803117
# cv_std_roc_auc                        0.002254
# cv_mean_recall                        0.775812
# cv_std_recall                         0.005435
# cv_mean_precision                     0.311138
# cv_std_precision                       0.00203
# cv_mean_f1                            0.444142
# cv_std_f1                             0.002253
# cv_mean_balanced_accuracy             0.727722
# cv_std_balanced_accuracy              0.002196
# holdout_accuracy                      0.694542
# holdout_average_precision             0.410788
# holdout_roc_auc                       0.805001
# holdout_recall                        0.782401
# holdout_precision                     0.311985
# holdout_f1                             0.44609
# holdout_balanced_accuracy             0.730277

# %% [markdown]
# ### Model #2 KNN
#
# KNN is still included for family coverage, but it is intentionally kept compact because distance-based models become expensive quickly once categorical one-hot features expand. We therefore use a reduced feature set, a capped training sample, and SMOTE inside the pipeline so the comparison stays fair without dominating runtime.

# %%
if KNN_MAX_TRAIN_ROWS is not None and len(train_df) > KNN_MAX_TRAIN_ROWS:
    _, knn_train_df = train_test_split(
        train_df,
        test_size=KNN_MAX_TRAIN_ROWS,
        stratify=train_df[target_col],
        random_state=RANDOM_STATE,
    )
else:
    knn_train_df = train_df.copy()

knn_preprocessor = ColumnTransformer(
    transformers=[
        (
            "cat",
            Pipeline(
                steps=[
                    ("imputer", SimpleImputer(strategy="constant", fill_value="missing")),
                    ("onehot", make_one_hot_encoder(dense=True)),
                ]
            ),
            knn_categorical,
        ),
        (
            "num",
            Pipeline(
                steps=[
                    ("imputer", SimpleImputer(strategy="median")),
                    ("scaler", StandardScaler()),
                ]
            ),
            structured_numeric,
        ),
    ]
)

knn_pipeline = ImbPipeline(
    steps=[
        ("preprocessor", knn_preprocessor),
        ("smote", SMOTE(random_state=RANDOM_STATE, sampling_strategy=0.55, k_neighbors=3)),
        ("model", KNeighborsClassifier()),
    ]
)

knn_grid = {
    "smote__sampling_strategy": [0.45, 0.55, 0.65],
    "model__n_neighbors": [21, 31, 51, 71],
    "model__weights": ["distance"],
    "model__p": [1, 2],
}

knn_search = GridSearchCV(
    estimator=knn_pipeline,
    param_grid=knn_grid,
    scoring=scoring,
    refit="f1",
    cv=cv,
    n_jobs=N_JOBS,
    verbose=1,
)

X_train_knn = knn_train_df[knn_features]
y_train_knn = knn_train_df[target_col]
X_test_knn = test_df[knn_features]
y_test_knn = test_df[target_col]

knn_search.fit(X_train_knn, y_train_knn)
knn_row, knn_scores = build_results_row("KNN", knn_search, X_test_knn, y_test_knn)

knn_holdout = test_df[["Complaint ID", "Product", "Issue", "Company", "narrative_present", target_col]].copy()
knn_holdout["model_family"] = "KNN"
knn_holdout["score"] = knn_scores["y_score"]
knn_holdout["prediction"] = knn_scores["y_pred"]

display(pd.DataFrame([knn_row]).T)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
#                                                                            0
# model_family                                                             KNN
# best_params                {'model__n_neighbors': 71, 'model__p': 1, 'mod...
# cv_mean_accuracy                                                    0.730533
# cv_std_accuracy                                                     0.005398
# cv_mean_average_precision                                           0.316769
# cv_std_average_precision                                            0.014546
# cv_mean_roc_auc                                                     0.736154
# cv_std_roc_auc                                                      0.011877
# cv_mean_recall                                                      0.547103
# cv_std_recall                                                       0.032014
# cv_mean_precision                                                   0.302382
# cv_std_precision                                                    0.009998
# cv_mean_f1                                                          0.389378
# cv_std_f1                                                           0.015767
# cv_mean_balanced_accuracy                                           0.655928
# cv_std_balanced_accuracy                                            0.014298
# holdout_accuracy                                                    0.731542
# holdout_average_precision                                           0.315573
# holdout_roc_auc                                                     0.739753
# holdout_recall                                                      0.548105
# holdout_precision                                                    0.30385
# holdout_f1                                                          0.390963
# holdout_balanced_accuracy                                           0.656932

# %% [markdown]
# ### Model #3 Random Forest
#
# Random Forest remains the main candidate for the final supervised workflow because it can mix nonlinear interactions across complaint context, company, and lightweight narrative indicators without forcing aggressive preprocessing assumptions. The final version gives it a broader hyperparameter search.

# %%
rf_preprocessor = ColumnTransformer(
    transformers=[
        (
            "cat",
            Pipeline(
                steps=[
                    ("imputer", SimpleImputer(strategy="constant", fill_value="missing")),
                    ("onehot", make_one_hot_encoder(dense=False)),
                ]
            ),
            rf_categorical,
        ),
        (
            "num",
            Pipeline(
                steps=[
                    ("imputer", SimpleImputer(strategy="median")),
                ]
            ),
            structured_numeric,
        ),
    ]
)

rf_pipeline = Pipeline(
    steps=[
        ("preprocessor", rf_preprocessor),
        (
            "model",
            RandomForestClassifier(
                n_estimators=RF_N_ESTIMATORS,
                class_weight="balanced_subsample",
                random_state=RANDOM_STATE,
                n_jobs=N_JOBS,
            ),
        ),
    ]
)

rf_grid = {
    "model__max_depth": [14, 22, None],
    "model__min_samples_leaf": [2, 5, 10],
    "model__min_samples_split": [5, 10],
    "model__max_features": ["sqrt", 0.5],
}

rf_search = GridSearchCV(
    estimator=rf_pipeline,
    param_grid=rf_grid,
    scoring=scoring,
    refit="f1",
    cv=cv,
    n_jobs=N_JOBS,
    verbose=1,
)

X_train_rf = train_df[rf_features]
y_train_rf = train_df[target_col]
X_test_rf = test_df[rf_features]
y_test_rf = test_df[target_col]

rf_search.fit(X_train_rf, y_train_rf)
rf_row, rf_scores = build_results_row("Random Forest", rf_search, X_test_rf, y_test_rf)

rf_holdout = test_df[["Complaint ID", "Product", "Issue", "Company", "narrative_present", target_col]].copy()
rf_holdout["model_family"] = "Random Forest"
rf_holdout["score"] = rf_scores["y_score"]
rf_holdout["prediction"] = rf_scores["y_pred"]

display(pd.DataFrame([rf_row]).T)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
#                                                                            0
# model_family                                                   Random Forest
# best_params                {'model__max_depth': None, 'model__max_feature...
# cv_mean_accuracy                                                    0.779604
# cv_std_accuracy                                                     0.001183
# cv_mean_average_precision                                           0.412487
# cv_std_average_precision                                            0.006142
# cv_mean_roc_auc                                                      0.80258
# cv_std_roc_auc                                                      0.001381
# cv_mean_recall                                                      0.599867
# cv_std_recall                                                       0.005149
# cv_mean_precision                                                   0.374482
# cv_std_precision                                                    0.002269
# cv_mean_f1                                                          0.461103
# cv_std_f1                                                           0.003029
# cv_mean_balanced_accuracy                                           0.706497
# cv_std_balanced_accuracy                                            0.002516
# holdout_accuracy                                                    0.778167
# holdout_average_precision                                           0.413141
# holdout_roc_auc                                                     0.805269
# holdout_recall                                                       0.61304
# holdout_precision                                                   0.374454
# holdout_f1                                                          0.464925
# holdout_balanced_accuracy                                           0.711004

# %% [markdown]
# ### Model #4 Support Vector Machine
#
# The linear SVM gives us another high-dimensional margin-based baseline. Like logistic regression, it benefits from the reduced final feature set and sentiment score, but it avoids the probability calibration overhead by using the raw decision margin for ranking metrics.

# %%
svm_categorical = [
    "Product",
    "Sub-product",
    "Issue",
    "Sub-issue",
    "Company",
    "Submitted via",
] + shared_topic_features
svm_features = svm_categorical + structured_numeric

svm_preprocessor = ColumnTransformer(
    transformers=[
        (
            "cat",
            Pipeline(
                steps=[
                    ("imputer", SimpleImputer(strategy="constant", fill_value="missing")),
                    ("onehot", make_one_hot_encoder(dense=False)),
                ]
            ),
            svm_categorical,
        ),
        (
            "num",
            Pipeline(
                steps=[
                    ("imputer", SimpleImputer(strategy="median")),
                    ("scaler", StandardScaler()),
                ]
            ),
            structured_numeric,
        ),
    ]
)

svm_pipeline = Pipeline(
    steps=[
        ("preprocessor", svm_preprocessor),
        ("model", LinearSVC(class_weight="balanced", random_state=RANDOM_STATE, dual="auto", max_iter=10000, tol=5e-4)),
    ]
)

svm_grid = {
    "model__C": [0.1, 0.25, 0.5, 1.0, 2.0],
}

svm_search = GridSearchCV(
    estimator=svm_pipeline,
    param_grid=svm_grid,
    scoring=scoring,
    refit="f1",
    cv=cv,
    n_jobs=N_JOBS,
    verbose=1,
)

X_train_svm = train_df[svm_features]
y_train_svm = train_df[target_col]
X_test_svm = test_df[svm_features]
y_test_svm = test_df[target_col]

svm_search.fit(X_train_svm, y_train_svm)
svm_row, svm_scores = build_results_row("Support Vector Machine", svm_search, X_test_svm, y_test_svm)

svm_holdout = test_df[["Complaint ID", "Product", "Issue", "Company", "narrative_present", target_col]].copy()
svm_holdout["model_family"] = "Support Vector Machine"
svm_holdout["score"] = svm_scores["y_score"]
svm_holdout["prediction"] = svm_scores["y_pred"]

display(pd.DataFrame([svm_row]).T)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
#                                                 0
# model_family               Support Vector Machine
# best_params                     {'model__C': 0.5}
# cv_mean_accuracy                         0.689781
# cv_std_accuracy                          0.002448
# cv_mean_average_precision                0.402369
# cv_std_average_precision                 0.001778
# cv_mean_roc_auc                          0.802987
# cv_std_roc_auc                           0.002558
# cv_mean_recall                           0.784957
# cv_std_recall                            0.005167
# cv_mean_precision                        0.308626
# cv_std_precision                         0.001766
# cv_mean_f1                               0.443047
# cv_std_f1                                0.002057
# cv_mean_balanced_accuracy                0.728494
# cv_std_balanced_accuracy                 0.002099
# holdout_accuracy                         0.689042
# holdout_average_precision                0.411227
# holdout_roc_auc                           0.80487
# holdout_recall                           0.789027
# holdout_precision                        0.308689
# holdout_f1                               0.443765
# holdout_balanced_accuracy                0.729709

# %% [markdown]
# ### Final Model Selection
#
# The final comparison is still ranked by cross-validated F1 so that model selection stays consistent with the project requirement. We still report the other metrics, but the main decision rule remains F1.

# %%
results_df = pd.DataFrame([logistic_row, knn_row, rf_row, svm_row]).sort_values(
    by="cv_mean_f1", ascending=False
).reset_index(drop=True)

comparison_columns = [
    "model_family",
    "cv_mean_accuracy",
    "cv_std_accuracy",
    "cv_mean_average_precision",
    "cv_std_average_precision",
    "cv_mean_roc_auc",
    "cv_std_roc_auc",
    "cv_mean_recall",
    "cv_std_recall",
    "cv_mean_precision",
    "cv_std_precision",
    "cv_mean_f1",
    "cv_std_f1",
    "holdout_accuracy",
    "holdout_average_precision",
    "holdout_roc_auc",
    "holdout_recall",
    "holdout_precision",
    "holdout_f1",
]
display(results_df[comparison_columns])

searches = {
    "Logistic Regression": logistic_search,
    "KNN": knn_search,
    "Random Forest": rf_search,
    "Support Vector Machine": svm_search,
}
holdout_frames = {
    "Logistic Regression": logistic_holdout,
    "KNN": knn_holdout,
    "Random Forest": rf_holdout,
    "Support Vector Machine": svm_holdout,
}

best_model_name = results_df.loc[0, "model_family"]
best_search = searches[best_model_name]
best_holdout = holdout_frames[best_model_name].sort_values("score", ascending=False).reset_index(drop=True)

print(f"Selected development model: {best_model_name}")
print(f"Best params: {best_search.best_params_}")

comparison_path = OUTPUT_TABLES_DIR / "final_relief_narrative_supervised_model_comparison.csv"
visuals_comparison_path = OUTPUT_TABLES_DIR / "03_final_narrative_model_comparison.csv"
holdout_path = ARTIFACT_DIR / "final_relief_narrative_best_model_holdout_predictions.parquet"
model_path = ARTIFACT_DIR / "best_final_relief_narrative_response_model.joblib"

results_df.to_csv(comparison_path, index=False)
results_df[comparison_columns].round(4).to_csv(visuals_comparison_path, index=False)
best_holdout.to_parquet(holdout_path, index=False)
joblib.dump(best_search.best_estimator_, model_path)

print(f"Saved comparison table to {comparison_path}")
print(f"Saved GitHub-friendly comparison table to {visuals_comparison_path}")
print(f"Saved holdout predictions to {holdout_path}")
print(f"Saved trained model to {model_path}")

best_holdout.head(10)
# Out:
#              model_family  cv_mean_accuracy  cv_std_accuracy  \
# 0           Random Forest          0.779604         0.001183
# 1     Logistic Regression          0.694750         0.002788
# 2  Support Vector Machine          0.689781         0.002448
# 3                     KNN          0.730533         0.005398
#
#    cv_mean_average_precision  cv_std_average_precision  cv_mean_roc_auc  \
# 0                   0.412487                  0.006142         0.802580
# 1                   0.402923                  0.001785         0.803117
# 2                   0.402369                  0.001778         0.802987
# 3                   0.316769                  0.014546         0.736154
#
#    cv_std_roc_auc  cv_mean_recall  cv_std_recall  cv_mean_precision  \
# 0        0.001381        0.599867       0.005149           0.374482
# 1        0.002254        0.775812       0.005435           0.311138
# 2        0.002558        0.784957       0.005167           0.308626
# 3        0.011877        0.547103       0.032014           0.302382
#
#    cv_std_precision  cv_mean_f1  cv_std_f1  holdout_accuracy  \
# 0          0.002269    0.461103   0.003029          0.778167
# 1          0.002030    0.444142   0.002253          0.694542
# 2          0.001766    0.443047   0.002057          0.689042
# 3          0.009998    0.389378   0.015767          0.731542
#
#    holdout_average_precision  holdout_roc_auc  holdout_recall  \
# 0                   0.413141         0.805269        0.613040
# 1                   0.410788         0.805001        0.782401
# 2                   0.411227         0.804870        0.789027
# 3                   0.315573         0.739753        0.548105
#
#    holdout_precision  holdout_f1
# 0           0.374454    0.464925
# 1           0.311985    0.446090
# 2           0.308689    0.443765
# 3           0.303850    0.390963
# Selected development model: Random Forest
# Best params: {'model__max_depth': None, 'model__max_features': 'sqrt', 'model__min_samples_leaf': 10, 'model__min_samples_split': 5}
# Saved comparison table to C:\Users\ntamm\OneDrive\Documents\1_MADS\1_Classes\696 - Milestone 2\Project\cfpb_mortgage_complaints\output_tables\final_relief_narrative_supervised_model_comparison.csv
# Saved GitHub-friendly comparison table to C:\Users\ntamm\OneDrive\Documents\1_MADS\1_Classes\696 - Milestone 2\Project\cfpb_mortgage_complaints\output_tables\03_final_narrative_model_comparison.csv
# Saved holdout predictions to C:\Users\ntamm\OneDrive\Documents\1_MADS\1_Classes\696 - Milestone 2\Project\cfpb_mortgage_complaints\data\processed\final_relief_narrative_best_model_holdout_predictions.parquet
# Saved trained model to C:\Users\ntamm\OneDrive\Documents\1_MADS\1_Classes\696 - Milestone 2\Project\cfpb_mortgage_complaints\data\processed\best_final_relief_narrative_response_model.joblib
#    Complaint ID                      Product  \
# 0      15818756                  Credit card
# 1      10101888                  Credit card
# 2       5028605  Credit card or prepaid card
# 3       6541114  Credit card or prepaid card
# 4       7971863                  Credit card
# 5       3074586  Checking or savings account
# 6       7073846  Credit card or prepaid card
# 7       5643011  Credit card or prepaid card
# 8       5326153  Credit card or prepaid card
# 9      15148479                  Credit card
#
#                                              Issue  \
# 0                                 Fees or interest
# 1                                 Fees or interest
# 2                                 Fees or interest
# 3  Problem with a purchase shown on your statement
# 4                                 Fees or interest
# 5                              Managing an account
# 6                                 Fees or interest
# 7                                 Fees or interest
# 8                                 Fees or interest
# 9                                 Fees or interest
#
#                                  Company  narrative_present  target_relief  \
# 0         Bread Financial Holdings, Inc.                  1              1
# 1         Bread Financial Holdings, Inc.                  1              1
# 2         Bread Financial Holdings, Inc.                  1              1
# 3  BANK OF AMERICA, NATIONAL ASSOCIATION                  1              0
# 4         Bread Financial Holdings, Inc.                  1              1
# 5  BANK OF AMERICA, NATIONAL ASSOCIATION                  1              0
# 6         Bread Financial Holdings, Inc.                  1              1
# 7         Bread Financial Holdings, Inc.                  1              1
# 8         Bread Financial Holdings, Inc.                  1              0
# 9         Bread Financial Holdings, Inc.                  1              1
#
#     model_family     score  prediction
# 0  Random Forest  0.853721           1
# 1  Random Forest  0.843519           1
# 2  Random Forest  0.839529           1
# 3  Random Forest  0.837477           1
# 4  Random Forest  0.837361           1
# 5  Random Forest  0.836669           1
# 6  Random Forest  0.835827           1
# 7  Random Forest  0.835430           1
# 8  Random Forest  0.835309           1
# 9  Random Forest  0.834165           1
